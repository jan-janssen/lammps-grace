# %%
# !lmp -in in.lammps
# Out:
# [jupyter-jan-janssen-lammps-grace-2szz5e4r:00652] mca_base_component_repository_open: unable to open mca_btl_openib: librdmacm.so.1: cannot open shared object file: No such file or directory (ignored)
# LAMMPS (27 Jun 2024)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:98)
#   using 1 OpenMP thread(s) per MPI task
# Lattice spacing in x,y,z = 4.05 4.05 4.05
# Created orthogonal box = (0 0 0) to (8.1 8.1 8.1)
#   1 by 1 by 1 MPI processor grid
# Created 32 atoms
#   using lattice units in orthogonal box = (0 0 0) to (8.1 8.1 8.1)
#   create_atoms CPU = 0.000 seconds
# ERROR: Unrecognized pair style 'grace' (src/force.cpp:275)
# Last command: pair_style grace pad_verbose
