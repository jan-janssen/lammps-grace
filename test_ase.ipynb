# %%
from ase.build import bulk

# %%
from tensorpotential.calculator import grace_fm
# Out:
# 2025-05-20 14:25:00.091568: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
structure = bulk("Al", cubic=True)

# %%
structure.calc = grace_fm("GRACE-2L-OMAT")
# Out:
# Using cached GRACE model from /home/jovyan/.cache/grace/GRACE-2L-OMAT
# Model license: Academic Software License

# %%
structure.get_total_energy()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747751103.911805     979 service.cc:146] XLA service 0x64648bff8190 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747751103.911849     979 service.cc:154]   StreamExecutor device (0): Host, Default Version
# 2025-05-20 14:25:04.152036: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1747751109.602443     979 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# -14.97543663561512
